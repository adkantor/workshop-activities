# %% [markdown]
# # Activity 6.01: Handling Outliers and Missing Data

# %% [markdown]
# In this activity, we will identify and get rid of outliers. Here, we have a CSV file. The goal here is to clean the data by using the knowledge that we have learned about so far and come up with a nicely formatted DataFrame. Identify the type of outliers and their effect on the data and clean the messy data.
#
# The dataset that we have used here can be found in the visit_data.csv file. This file contains data generated by a random data generator, and it contains people's names, their gender, email_id, ip_address, and the number of visits they made to a particular web page.

# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/visit_data.csv')
df
# Out:
#        id first_name  last_name                         email  gender  \
# 0       1      Sonny       Dahl              sdahl0@mysql.com    Male
# 1       2        NaN        NaN             dhoovart1@hud.gov     NaN
# 2       3        Gar      Armal        garmal2@technorati.com     NaN
# 3       4    Chiarra      Nulty         cnulty3@newyorker.com     NaN
# 4       5        NaN        NaN    sleaver4@elegantthemes.com     NaN
# ..    ...        ...        ...                           ...     ...
# 995   996     Averil   Pickover            apickoverrn@vk.com    Male
# 996   997     Walton  Hallewell         whallewellro@nasa.gov     NaN
# 997   998        NaN        NaN       ggallamorerp@meetup.com  Female
# 998   999   Sapphira     Terron       sterronrq@wordpress.org     NaN
# 999  1000        NaN        NaN  jandreuzzirr@paginegialle.it    Male
#
#           ip_address   visit
# 0      135.36.96.183  1225.0
# 1    237.165.194.143   919.0
# 2     166.43.137.224   271.0
# 3     139.98.137.108  1002.0
# 4      46.117.117.27  2434.0
# ..               ...     ...
# 995     10.45.16.167  1305.0
# 996  231.224.238.232  2531.0
# 997     118.65.94.40     NaN
# 998    24.77.234.208   250.0
# 999   211.136.66.144  2389.0
#
# [1000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  704 non-null    object
#  2   last_name   704 non-null    object
#  3   email       1000 non-null   object
#  4   gender      495 non-null    object
#  5   ip_address  1000 non-null   object
#  6   visit       974 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 54.8+ KB

# %%
df.describe(include='all')
# Out:
#                  id first_name last_name                email gender  \
# count   1000.000000        704       704                 1000    495
# unique          NaN        679       700                 1000      2
# top             NaN      Gerri     Isles  jputtick5t@gmpg.org   Male
# freq            NaN          3         2                    1    257
# mean     500.500000        NaN       NaN                  NaN    NaN
# std      288.819436        NaN       NaN                  NaN    NaN
# min        1.000000        NaN       NaN                  NaN    NaN
# 25%      250.750000        NaN       NaN                  NaN    NaN
# 50%      500.500000        NaN       NaN                  NaN    NaN
# 75%      750.250000        NaN       NaN                  NaN    NaN
# max     1000.000000        NaN       NaN                  NaN    NaN
#
#             ip_address        visit
# count             1000   974.000000
# unique            1000          NaN
# top     100.150.107.51          NaN
# freq                 1          NaN
# mean               NaN  1497.976386
# std                NaN   838.959460
# min                NaN     1.000000
# 25%                NaN   794.500000
# 50%                NaN  1477.000000
# 75%                NaN  2224.250000
# max                NaN  2998.000000

# %%
df_dup_removed = df.drop_duplicates()
df_dup_removed
# Out:
#        id first_name  last_name                         email  gender  \
# 0       1      Sonny       Dahl              sdahl0@mysql.com    Male
# 1       2        NaN        NaN             dhoovart1@hud.gov     NaN
# 2       3        Gar      Armal        garmal2@technorati.com     NaN
# 3       4    Chiarra      Nulty         cnulty3@newyorker.com     NaN
# 4       5        NaN        NaN    sleaver4@elegantthemes.com     NaN
# ..    ...        ...        ...                           ...     ...
# 995   996     Averil   Pickover            apickoverrn@vk.com    Male
# 996   997     Walton  Hallewell         whallewellro@nasa.gov     NaN
# 997   998        NaN        NaN       ggallamorerp@meetup.com  Female
# 998   999   Sapphira     Terron       sterronrq@wordpress.org     NaN
# 999  1000        NaN        NaN  jandreuzzirr@paginegialle.it    Male
#
#           ip_address   visit
# 0      135.36.96.183  1225.0
# 1    237.165.194.143   919.0
# 2     166.43.137.224   271.0
# 3     139.98.137.108  1002.0
# 4      46.117.117.27  2434.0
# ..               ...     ...
# 995     10.45.16.167  1305.0
# 996  231.224.238.232  2531.0
# 997     118.65.94.40     NaN
# 998    24.77.234.208   250.0
# 999   211.136.66.144  2389.0
#
# [1000 rows x 7 columns]

# %%
df_new = df.dropna(subset=['visit'], axis=0)
df_new
# Out:
#        id first_name  last_name                         email  gender  \
# 0       1      Sonny       Dahl              sdahl0@mysql.com    Male
# 1       2        NaN        NaN             dhoovart1@hud.gov     NaN
# 2       3        Gar      Armal        garmal2@technorati.com     NaN
# 3       4    Chiarra      Nulty         cnulty3@newyorker.com     NaN
# 4       5        NaN        NaN    sleaver4@elegantthemes.com     NaN
# ..    ...        ...        ...                           ...     ...
# 994   995        NaN        NaN            hlowethrm@army.mil  Female
# 995   996     Averil   Pickover            apickoverrn@vk.com    Male
# 996   997     Walton  Hallewell         whallewellro@nasa.gov     NaN
# 998   999   Sapphira     Terron       sterronrq@wordpress.org     NaN
# 999  1000        NaN        NaN  jandreuzzirr@paginegialle.it    Male
#
#           ip_address   visit
# 0      135.36.96.183  1225.0
# 1    237.165.194.143   919.0
# 2     166.43.137.224   271.0
# 3     139.98.137.108  1002.0
# 4      46.117.117.27  2434.0
# ..               ...     ...
# 994   104.234.36.172   747.0
# 995     10.45.16.167  1305.0
# 996  231.224.238.232  2531.0
# 998    24.77.234.208   250.0
# 999   211.136.66.144  2389.0
#
# [974 rows x 7 columns]

# %%
df_new['visit'].isna().sum()
# Out:
# 0

# %%
df_new.boxplot('visit')
# Out:
# <AxesSubplot:>

# %%
df['visit'].hist()
# Out:
# <AxesSubplot:>
