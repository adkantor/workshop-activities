# %% [markdown]
# # Using the VGG16 Network to Train a Deep Learning Network to Identify Images
#
# You are given an image of a motorbike. Use the VGG16 network to predict the image. Before you start, ensure that you have downloaded the image (test_image_1) to your working directory. To complete this activity, follow these steps:

# %% [markdown]
# ### 1. Import the required libraries, along with the VGG16 network.

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %% [markdown]
# ### 2. Initiate the pre-trained VGG16 model.

# %%
classifier = VGG16()

# %% [markdown]
# ### 3. Load the image that is going to be classified.
# ### 4. Preprocess the image by applying the transformations.

# %%
img = image.load_img('../Data/Prediction/test_image_1.jpg', target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1711B8B39E8>

# %%
img_trans = image.img_to_array(img)
img_trans = np.expand_dims(img_trans, axis=0)
img_trans = preprocess_input(img_trans)
img_trans.shape
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# ### 5. Create a predictor variable to predict the image.
# ### 6. Label the image and classify it.

# %%
y_pred = classifier.predict(img_trans)
y_pred.shape
# Out:
# (1, 1000)

# %%
decoded = decode_predictions(y_pred, top=5)
decoded
# Out:
# [[('n03785016', 'moped', 0.8468499),
#   ('n03791053', 'motor_scooter', 0.13869344),
#   ('n03127747', 'crash_helmet', 0.0067957775),
#   ('n03208938', 'disk_brake', 0.0022165852),
#   ('n04482393', 'tricycle', 0.00076244475)]]

# %%
label = decoded[0][0]
print(f'{label[1]}: {label[2] * 100:.2f}%')
# Out:
# moped: 84.68%
